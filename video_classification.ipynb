# %%
# !nvidia-smi
# Out:
# Wed Apr  5 13:29:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !rm -rf /content/*
# !pip install --upgrade --no-cache-dir gdown
# https://drive.google.com/file/d/1JGrBHwtTZY0wp9EbsQ-uiD5D9QirNaZ6/view?usp=sharing
# !gdown https://drive.google.com/uc?id=1JGrBHwtTZY0wp9EbsQ-uiD5D9QirNaZ6
# !unzip "/content/DCSASS Dataset.zip"
# !rm -rf "/content/DCSASS Dataset.zip"
# !mv "/content/DCSASS Dataset/Labels" /content/Labels
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_26.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_27.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_28.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_29.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_3.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_30.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_31.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_4.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_5.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_6.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_7.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_8.mp4
#   inflating: DCSASS Dataset/Robbery/Robbery150_x264.mp4/Robbery150_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/
#    creating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting002_x264.mp4/Shooting002_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting005_x264.mp4/Shooting005_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting007_x264.mp4/Shooting007_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting008_x264.mp4/Shooting008_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting009_x264.mp4/Shooting009_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting010_x264.mp4/Shooting010_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting011_x264.mp4/Shooting011_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting013_x264.mp4/Shooting013_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting015_x264.mp4/Shooting015_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting018_x264.mp4/Shooting018_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting019_x264.mp4/Shooting019_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting020_x264.mp4/Shooting020_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting021_x264.mp4/Shooting021_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting022_x264.mp4/Shooting022_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting025_x264.mp4/Shooting025_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting026_x264.mp4/Shooting026_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_10.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_11.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_12.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_13.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_14.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_15.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_16.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_17.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_18.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_19.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_2.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_20.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_21.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_22.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_23.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_24.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_25.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_26.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_27.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_28.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_29.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_3.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_30.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_31.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_4.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_5.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_6.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_7.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_8.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting028_x264.mp4/Shooting028_x264_9.mp4
#    creating: DCSASS Dataset/Shooting/Shooting029_x264.mp4/
#   inflating: DCSASS Dataset/Shooting/Shooting029_x264.mp4/Shooting029_x264_0.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting029_x264.mp4/Shooting029_x264_1.mp4
#   inflating: DCSASS Dataset/Shooting/Shooting029_x264.mp4/Shooting029_x264_10.mp4
# ...
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism042_x264.mp4/Vandalism042_x264_9.mp4
#    creating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_0.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_1.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_10.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_11.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_12.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_13.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_14.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_15.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_16.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_17.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_18.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism043_x264.mp4/Vandalism043_x264_9.mp4
#    creating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_0.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_1.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_10.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_11.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_12.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_13.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_14.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_15.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_16.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_17.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_18.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism044_x264.mp4/Vandalism044_x264_9.mp4
#    creating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_0.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_1.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_10.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_11.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_12.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_13.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_14.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_15.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_16.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_17.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_18.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism045_x264.mp4/Vandalism045_x264_9.mp4
#    creating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_0.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_1.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_10.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_11.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_12.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_13.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_14.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_15.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_16.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_17.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_18.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism046_x264.mp4/Vandalism046_x264_9.mp4
#    creating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_0.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_1.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_10.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_11.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_12.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_13.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_14.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_15.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_16.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_17.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_18.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_19.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_2.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_20.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_21.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_22.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_23.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_24.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_25.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_26.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_27.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_28.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_29.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_3.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_30.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_31.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_4.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_5.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_6.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_7.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_8.mp4
#   inflating: DCSASS Dataset/Vandalism/Vandalism047_x264.mp4/Vandalism047_x264_9.mp4

# %%
import pandas as pd

def filter_df(path):
    df = pd.read_csv(path,names=['file_name', 'label','class'])
    df['file_name'] = df['file_name'].apply(lambda x:x+'.mp4')
    df = df[df['class'] == 1]
    file_names = df['file_name'].unique().tolist()
    return file_names

# %%
import os
from tqdm.auto import tqdm
old_folder = os.path.join('/content','DCSASS Dataset')
labels_files = os.path.join('/content','Labels')
file_paths = {}

for i in tqdm(os.listdir(old_folder)):
    l1 = os.listdir(os.path.join(old_folder,i))
    path = os.path.join(labels_files,i+'.csv')
    files = filter_df(path)
    file_paths[i] = []
    for j in l1:
        l2 = os.listdir(os.path.join(old_folder,i,j))
        for k in l2:
            if k in files:
                file_paths[i].append(os.path.join(old_folder,i,j,k))
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
# !rm -rf video_data
# !mkdir video_data

# %%
new_folder = os.path.join('/content','video_data')
th = 50

for i,j in tqdm(file_paths.items()):
    os.mkdir(os.path.join(new_folder,i))
    for idx,k in enumerate(j):
        file_name = k.split('/')[-1]
        dest_path = os.path.join(new_folder,i,file_name)
        os.rename(k,dest_path)
        if (idx+1) == th:
            break
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
# !rm -rf "/content/DCSASS Dataset" /content/Labels

# %%
import os
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt
 
from moviepy.editor import *
# %matplotlib inline
 
from sklearn.model_selection import train_test_split

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))
 
# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('/content/video_data')
 
# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 12)
 
# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):
 
    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]
 
    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'/content/video_data/{selected_class_Name}')
 
    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)
 
    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'/content/video_data/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()
 
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
 
    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
os.listdir('/content/video_data')
# Out:
# ['Fighting',
#  'RoadAccidents',
#  'Stealing',
#  'Shooting',
#  'Assault',
#  'Robbery',
#  'Burglary',
#  'Arson',
#  'Abuse',
#  'Vandalism',
#  'Explosion',
#  'Shoplifting',
#  'Arrest']

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64
 
# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 20
 
# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "/content/video_data/"
 
# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ['Robbery',
 'Explosion',
 'Shoplifting',
 'Arrest',
 'Fighting',
 'RoadAccidents']

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''
 
    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)
 
    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
 
    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):
 
        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        # Reading the frame from the video. 
        success, frame = video_reader.read() 
 
        # Check if Video frame is not successfully read then break the loop
        if not success:
            break
 
        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''
 
    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)
 
            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)
 
            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:
 
                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)
 
    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: Robbery
# Extracting Data of Class: Explosion
# Extracting Data of Class: Shoplifting
# Extracting Data of Class: Arrest
# Extracting Data of Class: Fighting
# Extracting Data of Class: RoadAccidents

# %%
features.shape
# Out:
# (300, 20, 64, 64, 3)

# %%
labels.shape
# Out:
# (300,)

# %%
video_files_paths

# %%
one_hot_encoded_labels = tf.keras.utils.to_categorical(labels)

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)

# %%
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''
 
    # We will use a Sequential model for model construction
    model = tf.keras.Sequential()
 
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(tf.keras.layers.ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(tf.keras.layers.MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
    
    model.add(tf.keras.layers.ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(tf.keras.layers.MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
    
    model.add(tf.keras.layers.ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(tf.keras.layers.MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
    
    model.add(tf.keras.layers.ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(tf.keras.layers.MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    #model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(tf.keras.layers.Flatten()) 
    
    model.add(tf.keras.layers.Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %%
convlstm_model = create_convlstm_model()
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 20, 62, 62, 4)     1024
#
#  max_pooling3d (MaxPooling3D  (None, 20, 31, 31, 4)    0
#  )
#
#  time_distributed (TimeDistr  (None, 20, 31, 31, 4)    0
#  ibuted)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 20, 29, 29, 8)     3488
#
#  max_pooling3d_1 (MaxPooling  (None, 20, 15, 15, 8)    0
#  3D)
#
#  time_distributed_1 (TimeDis  (None, 20, 15, 15, 8)    0
#  tributed)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 20, 13, 13, 14)    11144
#
#  max_pooling3d_2 (MaxPooling  (None, 20, 7, 7, 14)     0
#  3D)
#
#  time_distributed_2 (TimeDis  (None, 20, 7, 7, 14)     0
#  tributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 20, 5, 5, 16)      17344
#
#  max_pooling3d_3 (MaxPooling  (None, 20, 3, 3, 16)     0
#  3D)
#
#  flatten (Flatten)           (None, 2880)              0
#
#  dense (Dense)               (None, 6)                 17286
#
# =================================================================
# Total params: 50,286
# Trainable params: 50,286
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
# Plot the structure of the contructed model.
tf.keras.utils.plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
 
# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 5, batch_size = 4,shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/5
# 45/45 [==============================] - 33s 273ms/step - loss: 1.7402 - accuracy: 0.2500 - val_loss: 1.4189 - val_accuracy: 0.5778
# Epoch 2/5
# 45/45 [==============================] - 11s 245ms/step - loss: 1.1503 - accuracy: 0.5944 - val_loss: 0.4748 - val_accuracy: 0.8444
# Epoch 3/5
# 45/45 [==============================] - 11s 236ms/step - loss: 0.6219 - accuracy: 0.7889 - val_loss: 0.3925 - val_accuracy: 0.7778
# Epoch 4/5
# 45/45 [==============================] - 12s 265ms/step - loss: 0.4677 - accuracy: 0.8278 - val_loss: 0.4447 - val_accuracy: 0.7333
# Epoch 5/5
# 45/45 [==============================] - 11s 255ms/step - loss: 0.2811 - accuracy: 0.9167 - val_loss: 0.1313 - val_accuracy: 0.9778

# %%
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 3/3 [==============================] - 1s 146ms/step - loss: 0.1021 - accuracy: 0.9867

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history
 
# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
 
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model_{current_date_time_string}.h5'
 
# Save your Model.
convlstm_model.save(model_file_name)

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))
 
    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)
 
    # Add title to the plot.
    plt.title(str(plot_name))
 
    # Add legend to the plot.
    plt.legend()

# %%
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
# !pip install mediapy

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''
 
    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)
 
    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
 
    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):
 
        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        # Reading the frame from the video. 
        success, frame = video_reader.read() 
 
        # Check if Video frame is not successfully read then break the loop
        if not success:
            break
 
        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Return the frames list.
    return frames_list

# %%
CLASSES_LIST
# Out:
# ['Robbery', 'Explosion', 'Shoplifting', 'Arrest', 'Fighting', 'RoadAccidents']

# %%
def vid_class_pred(path,class_list):
    arr = np.array(frames_extraction(path))
    arr = np.expand_dims(arr, axis=0)
    model_pred = convlstm_model.predict(arr).ravel()
    pred_prob = max(model_pred)
    pred_class = class_list[np.argmax(model_pred)]
    return pred_class,pred_prob

# %%
import mediapy as media
vid_path = '/content/video_data/Explosion/Explosion006_x264_19.mp4'

video = media.read_video(vid_path)
media.show_video(video, fps=30)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
pred,prob = vid_class_pred(vid_path,CLASSES_LIST)
pred,prob
# Out:
# 1/1 [==============================] - 0s 66ms/step
# ('Explosion', 0.9481985)
